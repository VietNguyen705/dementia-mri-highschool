# %% [markdown]
# # Dementia Prediction from Brain MRI: a Simple CNN
#
# **Title:** Simple Dementia Prediction from Brain MRI Images Using a Convolutional Neural Network.

# %% [markdown]
# ## Week 1 - Understand the problem
#
# **Goal:** learn what dementia is and why MRI images are useful.
#
# This week is **reading and writing only - no coding**. Learn the basic terms, read the OASIS dataset overview

# %% [markdown]
# ### Notes: understand the problem *(write your answer here)*
#
# Look these up:
#
# - **Dementia:**
# - **Alzheimer's disease:**
# - **MRI (Magnetic Resonance Imaging):**
# - **Brain atrophy:**
#
# **OASIS dataset - what is it?**
#
# **My exact task:** *(e.g. classify MRI images into dementia stages)*
#
# **Research question:** Can a simple CNN classify brain MRI images into four dementia-stage categories (Non-Demented, Very Mild, Mild, Moderate)?
#
# **Deliverables:** a 1-page background summary and your final research question.
#
# **Useful links** *(paste any helpful articles, videos, or docs here)*:
# -
# -

# %% [markdown]
# ## Week 2 - Download and organize the dataset
#
# **Goal:** prepare the image data. Set up Colab, download the OASIS dataset, count the images in each of the four classes, and check whether the classes are balanced or imbalanced.
#
# **Deliverable:** a dataset summary table (images per class).

# %%
# Download the OASIS Alzheimer's MRI dataset from Kaggle.
# It has four folders: Non Demented, Very mild Dementia, Mild Dementia, Moderate Dementia.
# TODO

# %%
# Dataset summary table: count images per class and check the balance.
# TODO

# %% [markdown]
# ## Week 3 - Explore the MRI images
#
# **Goals:** display sample MRIs from each class, check image size and color format, make a class-distribution chart, and write a short paragraph describing the dataset.

# %%
# Look at the brains: show one example MRI from each of the four classes.
# TODO

# %%
# Check the size and color format of a sample of images.
# TODO

# %%
# Make a clean class-distribution bar chart (save it for your paper).
# TODO

# %% [markdown]
# ### Notes: describe the dataset *(write your answer here)*
#
# Write a short paragraph (3-5 sentences) describing the dataset for your report:
# - How many images and how many classes?
# - What size and color are the images (grayscale or RGB)?
# - Are the classes balanced or imbalanced? Which class has the most / fewest images?
# - Why might the imbalance be a problem for training?

# %% [markdown]
# ## Week 4 - Preprocess the images
#
# **Goals:** resize every image to one size, normalize pixels to 0-1, and split into train / validation / test (70 / 15 / 15), stratified by class.

# %%
# Split the dataframe into train / validation / test (70/15/15), stratified by class.
# "Stratified" keeps the class balance the same in each split.
# TODO
#       passing stratify=labels
# TODO

# %%
# Build image pipelines that load, resize, and normalize the MRIs.
# TODO

# %%
# Look at one batch of training images to make sure the pipeline works.
# TODO

# %% [markdown]
# ### Notes: preprocessing choices *(write your answer here)*
#
# Briefly explain the choices you made and why:
# - What image size did you pick, and why?
# - Why normalize pixels to 0-1?
# - Why use a stratified split instead of a random one?

# %% [markdown]
# ## Week 5 - Build a simple CNN
#
# **Goals:** build a small Conv2D + MaxPooling network ending in a Dense softmax layer with 4 units (one per class).

# %%
# Build a simple CNN.
# Structure: Conv2D + MaxPooling, Conv2D + MaxPooling, Flatten, Dense, Dense(4, softmax).
# TODO

# %%
# Train the CNN.
# TODO

# %% [markdown]
# ## Week 6 - Train and evaluate the CNN
#
# **Goals:** measure accuracy, precision, recall, and F1, and look at a confusion matrix. Do NOT report accuracy only - recall matters because missing dementia cases is serious.

# %%
# Evaluate the model on the validation set with full metrics.
# TODO

# %%
# Confusion matrix.
# TODO

# %% [markdown]
# ### Notes: strongest and weakest classes *(write your answer here)*
#
# - Which class did the model classify **best**? Which **worst**?
# - Which classes get confused with each other (look at the confusion matrix)?
# - Why do you think the weakest class is hard? (hint: think about how many images it has)

# %% [markdown]
# ## Week 7 - Improve the model carefully
#
# **Goals:** try only 2-3 improvements (dropout, data augmentation, more epochs, ...) and keep a comparison table. Explain what helped and what did not.

# %%
# Improved CNN: add dropout and data augmentation, retrain, and record the result.
# TODO

# %%
# Make a results table comparing your model versions.
# TODO

# %% [markdown]
# ### Notes: what helped and what did not *(write your answer here)*
#
# For each change you tried (dropout, augmentation, more epochs, ...):
# - Did it improve accuracy / macro-F1, or not?
# - Why do you think it helped or hurt?
# - Which model version is your final best model?

# %% [markdown]
# ## Week 8 - Add explainability with Grad-CAM
#
# **Goals:** generate heatmaps that show which parts of the MRI influenced the prediction, for a few correct and incorrect examples.
#
# Keras provides an example Grad-CAM workflow: https://keras.io/examples/vision/grad_cam/?utm_source=chatgpt.com

# %%
# Grad-CAM: heatmap of the image regions that drove the prediction.
# TODO

# %%
# Show 2-4 Grad-CAM overlays.
# TODO

# %% [markdown]
# ### Notes: what does Grad-CAM show? *(write your answer here)*
#
# - For a correctly classified MRI, where did the CNN focus? Does it look at the brain or the background?
# - For a wrong prediction, where did it focus instead?
# - In one sentence: *the heatmap shows where the CNN looked when making its prediction.*

# %%
# Final score: evaluate your best model on the TEST set (only once, at the very end).
# The test set was never used for training or tuning, so it gives an honest final number.
# TODO

# %% [markdown]
# ## Week 9 & 10 - Write the paper & present
#
# **Goals:** draft an IEEE-style paper and prepare the final slides + 3-minute talk. This is writing, not coding - use the markdown cells below.

# %% [markdown]
# ### Paper draft
# IEEE Paper template: https://www.ieee.org/conferences/publishing/templates.html
#
# Write each section as you go (one short paragraph each to start):
#
# - **Abstract:** one-paragraph summary of the project and result.
# - **Introduction:** Why does early dementia detection from MRI matter?
# - **Background / Related Work:** what is OASIS? what are CNNs?
# - **Problem Definition:** given an MRI image X, predict a dementia-stage label y (4 classes).
# - **Methodology:** load, resize, normalize, split, train CNN, evaluate, Grad-CAM.
# - **Experimental Design:** baseline CNN vs improved CNN; same split and metrics.
# - **Results:** your comparison table, confusion matrix, and Grad-CAM figures.
# - **Discussion:** which class was easiest/hardest? did augmentation help?
# - **Limitations and Ethics:** not a medical diagnostic system; labels imperfect; possible patient leakage across splits; real use needs clinical validation.
# - **Conclusion:** answer your research question.
#
# **References** *(paste your sources / links here)*:
# -

# %% [markdown]
# ### Presentation plan *(write your answer here)*
#
# Plan your ~10 slides and 3-minute talk:
# 1. Title
# 2. Motivation
# 3. Research Question
# 4. Dataset
# 5. CNN Method
# 6. Experimental Design
# 7. Results
# 8. Grad-CAM Explainability
# 9. Limitations and Ethics
# 10. Conclusion
#
# *Notes / links for slides:*
